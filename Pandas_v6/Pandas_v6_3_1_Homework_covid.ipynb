# %%
import pandas  as pd
import seaborn as sns
import matplotlib.pyplot as plt

croped_covid_df = pd.read_csv('D:/Python обучение/Pandas_learning/Pandas/Pandas_stady/data/covid_data/croped_covid_df.csv') 

display(croped_covid_df)
# Out:
#             date         country  confirmed    deaths  recovered  \
# 0     2020-01-23       Australia        0.0       0.0        0.0
# 1     2020-01-25       Australia        4.0       0.0        0.0
# 2     2020-01-26       Australia        4.0       0.0        0.0
# 3     2020-01-27       Australia        5.0       0.0        0.0
# 4     2020-01-28       Australia        5.0       0.0        0.0
# ...          ...             ...        ...       ...        ...
# 2435  2021-05-25  United Kingdom  4483177.0  128001.0    15453.0
# 2436  2021-05-26  United Kingdom  4486168.0  128010.0    15477.0
# 2437  2021-05-27  United Kingdom  4489552.0  128020.0    15480.0
# 2438  2021-05-28  United Kingdom  4493582.0  128030.0    15480.0
# 2439  2021-05-29  United Kingdom  4496823.0  128037.0    15481.0
#
#       daily_confirmed  daily_deaths  daily_recovered  total_vaccinations  \
# 0                 NaN           NaN              NaN                 NaN
# ...
